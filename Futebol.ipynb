# %% [markdown]
# <a href="https://colab.research.google.com/github/Felipetds/Analise_de_dados-Brasileir-o-2019-/blob/main/Futebol.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Base de dados do campeonato brasileiro de 2019**
#
# 1° - Limpeza
#
# 1.   Remover campos sem dados
# 2.
#
# 2° - Análise
#
# 1.   Entender o que cada informação significa
# 2.
#
# 3° - Separar dados importantes
#
# 1.   Buscar informações úteis
# 2.   Remover informações que não serão utilizadas no momento

# %%
import pandas as pd

campeonato = pd.read_csv("brasileirao_serie_a.csv")
#campeonato.head()
campeonato_2019 = campeonato.query("ano_campeonato == 2019")

# %%
campeonato_2019.head()
# Out:
#       ano_campeonato        data horario  rodada  \
# 6270            2019  2019-04-27   09:00       1
# 6271            2019  2019-04-28   12:00       1
# 6272            2019  2019-04-28   12:00       1
# 6273            2019  2019-04-28   02:00       1
# 6274            2019  2019-04-28   04:00       1
#
#                               estadio                  arbitro  publico  \
# 6270  Estádio Cícero Pompeu de Toledo  Caio Max Augusto Vieira  26533.0
# 6271         Estádio Raimundo Sampaio   Rodolpho Toski Marques  10531.0
# 6272                      Arena Condá            Raphael Claus   8231.0
# 6273   Estádio Jornalista Mário Filho         Anderson Daronco  29459.0
# 6274                  Arena do Grêmio    Bruno Arleu de Araújo  34291.0
#
#       publico_max     time_man       time_vis  ... chutes_bola_parada_man  \
# 6270      67428.0    São Paulo       Botafogo  ...                    8.0
# 6271      23018.0  Atlético-MG        Avaí FC  ...                   18.0
# 6272      22600.0  Chapecoense  Internacional  ...                   12.0
# 6273      78838.0     Flamengo       Cruzeiro  ...                   19.0
# 6274      60540.0       Grêmio      Santos FC  ...                   19.0
#
#      chutes_bola_parada_vis  defesas_man  defesas_vis  impedimentos_man  \
# 6270                   21.0          2.0          2.0               2.0
# 6271                   11.0          0.0          1.0               0.0
# 6272                   15.0          6.0          5.0               0.0
# 6273                   13.0          0.0          2.0               0.0
# 6274                   15.0          3.0          9.0               2.0
#
#       impedimentos_vis  chutes_man  chutes_vis  chutes_fora_man  \
# 6270               1.0         4.0         2.0              1.0
# 6271               2.0         3.0         1.0              8.0
# 6272               2.0         7.0         6.0              4.0
# 6273               1.0         5.0         1.0              5.0
# 6274               1.0        11.0         5.0              8.0
#
#       chutes_fora_vis
# 6270              2.0
# 6271              4.0
# 6272              9.0
# 6273              0.0
# 6274              3.0
#
# [5 rows x 36 columns]

# %%
teste_ida = campeonato_2019.query("time_vis == 'Flamengo'")
teste_volta = campeonato_2019.query("time_man == 'Flamengo'")

teste_ida = teste_ida[['data', 'ano_campeonato', 'time_man', 'time_vis', 'gols_man', 'gols_vis']]
teste_volta = teste_volta[['data', 'ano_campeonato', 'time_man', 'time_vis', 'gols_man', 'gols_vis']]

#gols_ida = teste_ida.sum()["gols_vis"]
#gols_volta = teste_volta.sum()["gols_man"]

#gols = gols_ida + gols_volta
#gols

vitorias_casa = teste_volta.query("gols_man > gols_vis")
vitorias_fcasa = teste_ida.query("gols_vis > gols_man")

empates_casa = teste_volta.query("gols_man == gols_vis")
empates_fcasa = teste_ida.query("gols_vis == gols_man")

derrotas_casa = teste_volta.query("gols_man < gols_vis")
derrotas_fcasa = teste_ida.query("gols_vis < gols_man")

vitorias_casa = len(vitorias_casa)
vitorias_fcasa = len(vitorias_fcasa)

empates_casa = len(empates_casa)
empates_fcasa = len(empates_fcasa)

derrotas_casa = len(derrotas_casa)
derrotas_fcasa = len(derrotas_fcasa)

total_vitorias = vitorias_casa + vitorias_fcasa
total_empates = empates_casa + empates_fcasa
total_derrotas = derrotas_casa + derrotas_fcasa

total_vitorias, total_empates, total_derrotas
# Out:
# (28, 6, 4)

# %%
times = campeonato_2019.groupby('time_man').count()
#times = times[['time_man']]
#times = times.drop('gols_man')
#times
#times.drop(['gols_man'])
times# = times[times]
teste = times[2]
#for i in range(19):
#  print(times[i])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# /usr/local/lib/python3.7/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.7/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 2
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-5-8c948707e7e7> in <module>()
#       5 #times.drop(['gols_man'])
#       6 times# = times[times]
# ----> 7 teste = times[2]
#       8 #for i in range(19):
#       9 #  print(times[i])
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    3456             if self.columns.nlevels > 1:
#    3457                 return self._getitem_multilevel(key)
# -> 3458             indexer = self.columns.get_loc(key)
#    3459             if is_integer(indexer):
#    3460                 indexer = [indexer]
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
# -> 3363                 raise KeyError(key) from err
#    3364
#    3365         if is_scalar(key) and isna(key) and not self.hasnans:
#
# KeyError: 2

# %%
#times = campeonato_2019.groupby('time_man').count()

times = campeonato_2019.groupby('time_man').count()
times = times.drop(columns=['data','ano_campeonato','horario','rodada','estadio','arbitro','publico','publico_max','time_vis','tecnico_man'])
times
# Out:
#                tecnico_vis  colocacao_man  colocacao_vis  \
# time_man
# Athletico-PR            19             19             19
# Atlético-MG             19             19             19
# Avaí FC                 19             19             19
# Botafogo                19             19             19
# CSA                     19             19             19
# Ceará SC                19             19             19
# Chapecoense             19             19             19
# Corinthians             19             19             19
# Cruzeiro                19             19             19
# EC Bahia                19             19             19
# Flamengo                19             19             19
# Fluminense              19             19             19
# Fortaleza               19             19             19
# Goiás EC                19             19             19
# Grêmio                  19             19             19
# Internacional           19             19             19
# Palmeiras               19             19             19
# Santos FC               19             19             19
# São Paulo               19             19             19
# Vasco da Gama           19             19             19
#
#                valor_equipe_titular_man  valor_equipe_titular_vis  \
# time_man
# Athletico-PR                         19                        19
# Atlético-MG                          19                        19
# Avaí FC                              19                        19
# Botafogo                             19                        19
# CSA                                  19                        19
# Ceará SC                             19                        19
# Chapecoense                          19                        19
# Corinthians                          19                        19
# Cruzeiro                             19                        19
# EC Bahia                             19                        19
# Flamengo                             19                        19
# Fluminense                           19                        19
# Fortaleza                            19                        19
# Goiás EC                             19                        19
# Grêmio                               19                        19
# Internacional                        19                        19
# Palmeiras                            19                        19
# Santos FC                            19                        19
# São Paulo                            19                        19
# Vasco da Gama                        19                        19
#
#                idade_media_titular_man  idade_media_titular_vis  gols_man  \
# time_man
# Athletico-PR                        19                       19        19
# Atlético-MG                         19                       19        19
# Avaí FC                             19                       19        19
# Botafogo                            19                       19        19
# CSA                                 19                       19        19
# Ceará SC                            19                       19        19
# Chapecoense                         19                       19        19
# Corinthians                         19                       19        19
# Cruzeiro                            19                       19        19
# EC Bahia                            19                       19        19
# Flamengo                            19                       19        19
# Fluminense                          19                       19        19
# Fortaleza                           19                       19        19
# Goiás EC                            19                       19        19
# Grêmio                              19                       19        19
# Internacional                       19                       19        19
# Palmeiras                           19                       19        19
# Santos FC                           19                       19        19
# São Paulo                           19                       19        19
# Vasco da Gama                       19                       19        19
#
#                gols_vis  gols_1_tempo_man  ...  chutes_bola_parada_man  \
# time_man                                   ...
# Athletico-PR         19                19  ...                       8
# Atlético-MG          19                19  ...                       9
# Avaí FC              19                19  ...                       8
# Botafogo             19                19  ...                      10
# CSA                  19                19  ...                       6
# Ceará SC             19                19  ...                       9
# Chapecoense          19                19  ...                       9
# Corinthians          19                19  ...                       9
# Cruzeiro             19                19  ...                      10
# EC Bahia             19                19  ...                       8
# Flamengo             19                19  ...                       8
# Fluminense           19                19  ...                       7
# Fortaleza            19                19  ...                      10
# Goiás EC             19                19  ...                       9
# Grêmio               19                19  ...                       7
# Internacional        19                19  ...                       9
# Palmeiras            19                19  ...                       7
# Santos FC            19                19  ...                       9
# São Paulo            19                19  ...                       9
# Vasco da Gama        19                19  ...                       7
#
#                chutes_bola_parada_vis  defesas_man  defesas_vis  \
# time_man
# Athletico-PR                        8            8            8
# Atlético-MG                         9            9            9
# Avaí FC                             8            8            8
# Botafogo                           10           10           10
# CSA                                 6            6            6
# Ceará SC                            9            9            9
# Chapecoense                         9            9            9
# Corinthians                         9            9            9
# Cruzeiro                           10           10           10
# EC Bahia                            8            8            8
# Flamengo                            8            8            8
# Fluminense                          7            7            7
# Fortaleza                          10           10           10
# Goiás EC                            9            9            9
# Grêmio                              7            7            7
# Internacional                       9            9            9
# Palmeiras                           7            7            7
# Santos FC                           9            9            9
# São Paulo                           9            9            9
# Vasco da Gama                       7            7            7
#
#                impedimentos_man  impedimentos_vis  chutes_man  chutes_vis  \
# time_man
# Athletico-PR                  8                 8           8           8
# Atlético-MG                   9                 9           9           9
# Avaí FC                       8                 8           8           8
# Botafogo                     10                10          10          10
# CSA                           6                 6           6           6
# Ceará SC                      9                 9           9           9
# Chapecoense                   9                 9           9           9
# Corinthians                   9                 9           9           9
# Cruzeiro                     10                10          10          10
# EC Bahia                      8                 8           8           8
# Flamengo                      8                 8           8           8
# Fluminense                    7                 7           7           7
# Fortaleza                    10                10          10          10
# Goiás EC                      9                 9           9           9
# Grêmio                        7                 7           7           7
# Internacional                 9                 9           9           9
# Palmeiras                     7                 7           7           7
# Santos FC                     9                 9           9           9
# São Paulo                     9                 9           9           9
# Vasco da Gama                 7                 7           7           7
#
#                chutes_fora_man  chutes_fora_vis
# time_man
# Athletico-PR                 8                8
# Atlético-MG                  9                9
# Avaí FC                      8                8
# Botafogo                    10               10
# CSA                          6                6
# Ceará SC                     9                9
# Chapecoense                  9                9
# Corinthians                  9                9
# Cruzeiro                    10               10
# EC Bahia                     8                8
# Flamengo                     8                8
# Fluminense                   7                7
# Fortaleza                   10               10
# Goiás EC                     9                9
# Grêmio                       7                7
# Internacional                9                9
# Palmeiras                    7                7
# Santos FC                    9                9
# São Paulo                    9                9
# Vasco da Gama                7                7
#
# [20 rows x 25 columns]

# %%
time_2 = pd.Series({'time':'Athletico-PR','gols':'51'})
time_2
time_1 = pd.Series({'time':'Flamengo','gols':'86'}) 
time_1
lista_times = pd.DataFrame([time_2, time_1])
lista_times = lista_times.set_index("time")
lista_times
# Out:
#              gols
# time
# Athletico-PR   51
# Flamengo       86

# %%
lista_times = pd.DataFrame([time_2, time_1])
lista_times = lista_times.set_index("time")
lista_times
# Out:
#              gols
# time
# Athletico-PR   51
# Flamengo       86

# %%
times = campeonato_2019.iloc[:,[8]]
times = times.drop_duplicates()


for i in range(20):
  print(times.iloc[i]['time_man'])
# Out:
# São Paulo
# Atlético-MG
# Chapecoense
# Flamengo
# Grêmio
# Ceará SC
# EC Bahia
# Athletico-PR
# Palmeiras
# Fluminense
# CSA
# Corinthians
# Internacional
# Cruzeiro
# Avaí FC
# Vasco da Gama
# Goiás EC
# Fortaleza
# Santos FC
# Botafogo

# %%
times_teste = []
s_gols = []

for i in range(20):

  nome = times.iloc[i]['time_man']
  #nome = str(nome)
  teste_ida = campeonato_2019.query("time_man == @nome")
  teste_volta = campeonato_2019.query("time_vis == @nome")
  teste_ida = teste_ida[['data', 'ano_campeonato', 'time_man', 'time_vis', 'gols_man', 'gols_vis']]
  teste_volta = teste_volta[['data', 'ano_campeonato', 'time_man', 'time_vis', 'gols_man', 'gols_vis']]

  gols_ida = teste_ida.sum()["gols_vis"]
  gols_volta = teste_volta.sum()["gols_man"]

  gols = gols_ida + gols_volta

  times_teste.append(nome)
  s_gols.append(gols)

times_teste, s_gols
# Out:
# (['São Paulo',
#   'Atlético-MG',
#   'Chapecoense',
#   'Flamengo',
#   'Grêmio',
#   'Ceará SC',
#   'EC Bahia',
#   'Athletico-PR',
#   'Palmeiras',
#   'Fluminense',
#   'CSA',
#   'Corinthians',
#   'Internacional',
#   'Cruzeiro',
#   'Avaí FC',
#   'Vasco da Gama',
#   'Goiás EC',
#   'Fortaleza',
#   'Santos FC',
#   'Botafogo'],
#  [30.0,
#   49.0,
#   52.0,
#   37.0,
#   39.0,
#   41.0,
#   43.0,
#   32.0,
#   32.0,
#   46.0,
#   58.0,
#   34.0,
#   39.0,
#   46.0,
#   62.0,
#   45.0,
#   64.0,
#   49.0,
#   33.0,
#   45.0])

# %%
gols_levados = pd.DataFrame([times_teste, s_gols])
#lista_times = lista_times.set_index("time")
gols_levados = gols_levados.transpose()
#gols_feitos = gols_feitos.columns = ['times','gols_feitos']
#gols_feitos = gols_feitos.columns = ["times","gols_feitos"]
gols_levados
# Out:
#                 0     1
# 0       São Paulo  30.0
# 1     Atlético-MG  49.0
# 2     Chapecoense  52.0
# 3        Flamengo  37.0
# 4          Grêmio  39.0
# 5        Ceará SC  41.0
# 6        EC Bahia  43.0
# 7    Athletico-PR  32.0
# 8       Palmeiras  32.0
# 9      Fluminense  46.0
# 10            CSA  58.0
# 11    Corinthians  34.0
# 12  Internacional  39.0
# 13       Cruzeiro  46.0
# 14        Avaí FC  62.0
# 15  Vasco da Gama  45.0
# 16       Goiás EC  64.0
# 17      Fortaleza  49.0
# 18      Santos FC  33.0
# 19       Botafogo  45.0

# %%
times_teste = []
vit = []
emp = []
der = []

for i in range(20):

  nome = times.iloc[i]['time_man']

  teste_ida = campeonato_2019.query("time_vis == @nome")
  teste_volta = campeonato_2019.query("time_man == @nome")

  teste_ida = teste_ida[['data', 'ano_campeonato', 'time_man', 'time_vis', 'gols_man', 'gols_vis']]
  teste_volta = teste_volta[['data', 'ano_campeonato', 'time_man', 'time_vis', 'gols_man', 'gols_vis']]

  vitorias_casa = teste_volta.query("gols_man > gols_vis")
  vitorias_fcasa = teste_ida.query("gols_vis > gols_man")

  empates_casa = teste_volta.query("gols_man == gols_vis")
  empates_fcasa = teste_ida.query("gols_vis == gols_man")

  derrotas_casa = teste_volta.query("gols_man < gols_vis")
  derrotas_fcasa = teste_ida.query("gols_vis < gols_man")

  vitorias_casa = len(vitorias_casa)
  vitorias_fcasa = len(vitorias_fcasa)

  empates_casa = len(empates_casa)
  empates_fcasa = len(empates_fcasa)

  derrotas_casa = len(derrotas_casa)
  derrotas_fcasa = len(derrotas_fcasa)

  total_vitorias = vitorias_casa + vitorias_fcasa
  total_empates = empates_casa + empates_fcasa
  total_derrotas = derrotas_casa + derrotas_fcasa

  times_teste.append(nome)
  vit.append(total_vitorias)
  emp.append(total_empates)
  der.append(total_derrotas)
# Out:
# (13, 4, 21)

# %%
desempenho = pd.DataFrame([times_teste, vit, emp, der])
#lista_times = lista_times.set_index("time")
desempenho = desempenho.transpose()
#gols_feitos = gols_feitos.columns = ['times','gols_feitos']
#gols_feitos = gols_feitos.columns = ["times","gols_feitos"]
desempenho
# Out:
#                 0   1   2   3
# 0       São Paulo  17  12   9
# 1     Atlético-MG  13   9  16
# 2     Chapecoense   7  11  20
# 3        Flamengo  28   6   4
# 4          Grêmio  19   8  11
# 5        Ceará SC  10   9  19
# 6        EC Bahia  12  13  13
# 7    Athletico-PR  18  10  10
# 8       Palmeiras  21  11   6
# 9      Fluminense  12  10  16
# 10            CSA   8   8  22
# 11    Corinthians  14  14  10
# 12  Internacional  16   9  13
# 13       Cruzeiro   7  15  16
# 14        Avaí FC   3  11  24
# 15  Vasco da Gama  12  13  13
# 16       Goiás EC  15   7  16
# 17      Fortaleza  15   8  15
# 18      Santos FC  22   8   8
# 19       Botafogo  13   4  21
